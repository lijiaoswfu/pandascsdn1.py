# %%
import pandas as pd

data = pd.Series()
print('默认的空序列:',data)
# Out:
# 默认的空序列: Series([], dtype: float64)

# %%
import pandas as pd

data = pd.Series(5,index=[0,1,2])
print(data)
# Out:
# 0    5
# 1    5
# 2    5
# dtype: int64

# %%
import pandas as pd

data = pd.Series(5,index=[0,1,2])
data2 = pd.Series(3,index=['a','b','c'])
print(data)
print(data2)
# Out:
# 0    5
# 1    5
# 2    5
# dtype: int64
# a    3
# b    3
# c    3
# dtype: int64

# %%
import pandas as pd
import numpy as np

initdata = np.array(['hello','world','pyton'])
data = pd.Series(initdata)
print(data)
# Out:
# 0    hello
# 1    world
# 2    pyton
# dtype: object

# %%
import pandas as pd
import numpy as np

initdata = np.array(['hello','world','pyton'])
data = pd.Series(initdata,index=[1,2,3])
print(data)
# Out:
# 1    hello
# 2    world
# 3    pyton
# dtype: object

# %%
import pandas as pd

initdata = {'name':'ivy','age':10}
data = pd.Series(initdata)
print(data)
# Out:
# name    ivy
# age      10
# dtype: object

# %%
import pandas as pd

df = pd.DataFrame()
print(df)
# 创建空数据帧
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

data = [{'name':'Wilson','age':15},{'name':'Lijiao','age':40}]
df = pd.DataFrame(data)
print(df)
# Out:
#    age    name
# 0   15  Wilson
# 1   40  Lijiao

# %%
import pandas as pd

data = [{'name':['Wilson','Lijiao'],'age':[15,40]}]
df = pd.DataFrame(data)
print(df)
#通过列表创建数据帧
# Out:
#         age              name
# 0  [15, 40]  [Wilson, Lijiao]

# %%
import pandas as pd

series = {"name":pd.Series(['Wilson','Bruce','Chelsea'],index=['user1','user2','user3']),'age':pd.Series([15,24,19],index=['user1','user2','user3']),'gender':pd.Series(['man','man','woman'],index=['user1','user2','user3'])}
df = pd.DataFrame(series)
print(df)
print('选取第一行数据：')
print(df.loc['user1'])
print('')
print('选取第三行数据：')
print(df.loc['user3'])
# Out:
#           name  age gender
# user1   Wilson   15    man
# user2    Bruce   24    man
# user3  Chelsea   19  woman
# 选取第一行数据：
# name      Wilson
# age           15
# gender       man
# Name: user1, dtype: object
#
# 选取第三行数据：
# name      Chelsea
# age            19
# gender      woman
# Name: user3, dtype: object

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B','110-A','110-C','210-A','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])

print(df.shape())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
#      10   columns =['id','date','city','category','age','price'])
#      11
# ---> 12 print(df.shape())
#
# TypeError: 'tuple' object is not callable

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B','110-A','110-C','210-A','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])

print(df.shape)
# Out:
# (6, 6)

# %%
import numpy as np
import pandas as pd
# 添加引用

df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B','110-A','110-C','210-A','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])
# 创建数据帧

print(df.shape)  #维度查看
print(df.info()) # 数据表基本信息（维度、列名称、数据格式、所占空间等）：
# Out:
# (6, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
# id          6 non-null int64
# date        6 non-null datetime64[ns]
# city        6 non-null object
# category    6 non-null object
# age         6 non-null int64
# price       4 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 368.0+ bytes
# None

# %%
import numpy as np
import pandas as pd
# 添加引用

df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B','110-A','110-C','210-A','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])
# 创建数据帧

print(df.shape)  # 维度查看
print(df.info()) # 数据表基本信息（维度、列名称、数据格式、所占空间等）：
print(df.dtypes) # 每一列数据的格式
# Out:
# (6, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
# id          6 non-null int64
# date        6 non-null datetime64[ns]
# city        6 non-null object
# category    6 non-null object
# age         6 non-null int64
# price       4 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 368.0+ bytes
# None
# id                   int64
# date        datetime64[ns]
# city                object
# category            object
# age                  int64
# price              float64
# dtype: object

# %%
import numpy as np
import pandas as pd
# 添加引用

df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B','110-A','110-C','210-A','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])
# 创建数据帧

print(df.shape)  # 维度查看
print(df.info()) # 数据表基本信息（维度、列名称、数据格式、所占空间等）：
print(df.dtypes) # 每一列数据的格式
print(df['city'].dtype) # 某一列格式
# Out:
# (6, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
# id          6 non-null int64
# date        6 non-null datetime64[ns]
# city        6 non-null object
# category    6 non-null object
# age         6 non-null int64
# price       4 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 368.0+ bytes
# None
# id                   int64
# date        datetime64[ns]
# city                object
# category            object
# age                  int64
# price              float64
# dtype: object
# object

# %%
print(df.isnull())
# Out:
#       id   date   city  category    age  price
# 0  False  False  False     False  False  False
# 1  False  False  False     False  False   True
# 2  False  False  False     False  False  False
# 3  False  False  False     False  False  False
# 4  False  False  False     False  False   True
# 5  False  False  False     False  False  False

# %%
print(df['city'].isnull())  # 查看某一列是否空值
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: city, dtype: bool

# %%
print(df['city'].unique()) # 查看某一列唯一值
# Out:
# ['Beijing ' 'SH' ' guangzhou ' 'Shenzhen' 'shanghai' 'BEIJING ']

# %%
print(df.values) # 查看数据表的值
# Out:
# [[1001 Timestamp('2013-01-02 00:00:00') 'Beijing ' '100-A' 23 1200.0]
#  [1002 Timestamp('2013-01-03 00:00:00') 'SH' '100-B' 44 nan]
#  [1003 Timestamp('2013-01-04 00:00:00') ' guangzhou ' '110-A' 54 2133.0]
#  [1004 Timestamp('2013-01-05 00:00:00') 'Shenzhen' '110-C' 32 5433.0]
#  [1005 Timestamp('2013-01-06 00:00:00') 'shanghai' '210-A' 34 nan]
#  [1006 Timestamp('2013-01-07 00:00:00') 'BEIJING ' '130-F' 32 4432.0]]

# %%
print(df.columns)  # 查看列名
# Out:
# Index(['id', 'date', 'city', 'category', 'age', 'price'], dtype='object')

# %%
print(df.head())  # 查看前五行数据
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN

# %%
print(df.tail())  # 查看后五行数据
# Out:
#      id       date         city category  age   price
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df.fillna(value=0)) # 对空值用0填充
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     0.0
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     0.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B',' ','110-C',' ','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])

# %%
print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df['price'].fillna(df['price'].mean))  # 使用列prince的均值对NA进行填充
# Out:
# 0                                                 1200
# 1    <bound method Series.mean of 0    1200.0\n1   ...
# 2                                                 2133
# 3                                                 5433
# 4    <bound method Series.mean of 0    1200.0\n1   ...
# 5                                                 4432
# Name: price, dtype: object

# %%
print(df.fillna(value=0)) # 对空值用0填充
print(df['price'].fillna(df['price'].mean))  # 使用列prince的均值对NA进行填充
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     0.0
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     0.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0
# 0                                                 1200
# 1    <bound method Series.mean of 0    1200.0\n1   ...
# 2                                                 2133
# 3                                                 5433
# 4    <bound method Series.mean of 0    1200.0\n1   ...
# 5                                                 4432
# Name: price, dtype: object

# %%
df['price'].fillna(df['price'].mean)  # 使用列prince的均值对NA进行填充
# Out:
# 0                                                 1200
# 1    <bound method Series.mean of 0    1200.0\n1   ...
# 2                                                 2133
# 3                                                 5433
# 4    <bound method Series.mean of 0    1200.0\n1   ...
# 5                                                 4432
# Name: price, dtype: object

# %%
df['city']=df['city'].map(str.strip)
print(df)  # 清除city字段的字符空格
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    Beijing    100-A   23  1200.0
# 1  1002 2013-01-03         SH    100-B   44     NaN
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34     NaN
# 5  1006 2013-01-07    BEIJING    130-F   32  4432.0

# %%
df['city']=df['city'].str.lower()
print(df) # 大小写转换
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44     NaN
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34     NaN
# 5  1006 2013-01-07    beijing    130-F   32  4432.0

# %%
df['city']=df['city'].str.upper()
print(df) # 大小写转换 upper
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    BEIJING    100-A   23  1200.0
# 1  1002 2013-01-03         SH    100-B   44     NaN
# 2  1003 2013-01-04  GUANGZHOU            54  2133.0
# 3  1004 2013-01-05   SHENZHEN    110-C   32  5433.0
# 4  1005 2013-01-06   SHANGHAI            34     NaN
# 5  1006 2013-01-07    BEIJING    130-F   32  4432.0

# %%
print(df['price'].astype('int') )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 print(df['price'].astype('int') )
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
print(df['price'].astype('int'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 print(df['price'].astype('int'))
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
df['price'].astype('int')
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 df['price'].astype('int')
#       2 print(df)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
df['price'].fillna(df['price'].mean)  # 使用列prince的均值对NA进行填充
# Out:
# 0                                                 1200
# 1    <bound method Series.mean of 0    1200.0\n1   ...
# 2                                                 2133
# 3                                                 5433
# 4    <bound method Series.mean of 0    1200.0\n1   ...
# 5                                                 4432
# Name: price, dtype: object

# %%
df['price'].fillna(df['price'].mean)  # 使用列prince的均值对NA进行填充
print(df)
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    BEIJING    100-A   23  1200.0
# 1  1002 2013-01-03         SH    100-B   44     NaN
# 2  1003 2013-01-04  GUANGZHOU            54  2133.0
# 3  1004 2013-01-05   SHENZHEN    110-C   32  5433.0
# 4  1005 2013-01-06   SHANGHAI            34     NaN
# 5  1006 2013-01-07    BEIJING    130-F   32  4432.0

# %%
df['price'].fillna(df['price'].mean)  # 使用列prince的均值对NA进行填充
# Out:
# 0                                                 1200
# 1    <bound method Series.mean of 0    1200.0\n1   ...
# 2                                                 2133
# 3                                                 5433
# 4    <bound method Series.mean of 0    1200.0\n1   ...
# 5                                                 4432
# Name: price, dtype: object

# %%
df['price'].fillna(df['price'].mean)
# Out:
# 0                                                 1200
# 1    <bound method Series.mean of 0    1200.0\n1   ...
# 2                                                 2133
# 3                                                 5433
# 4    <bound method Series.mean of 0    1200.0\n1   ...
# 5                                                 4432
# Name: price, dtype: object

# %%
df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B',' ','110-C',' ','130-F'],
  "price":[1200,np.nan,2133,5433,500,4432]},
  columns =['id','date','city','category','age','price'])
# 创建数据帧

print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34   500.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df['price'].fillna(df['price'].mean)
# Out:
# 0                                                 1200
# 1    <bound method Series.mean of 0    1200.0\n1   ...
# 2                                                 2133
# 3                                                 5433
# 4                                                  500
# 5                                                 4432
# Name: price, dtype: object

# %%
df['prince'].fillna(df['prince'].mean())  # 使用列prince的均值对NA进行填充
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prince'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ...

# %%
df['price'].fillna(df['price'].mean())  # 使用列prince的均值对NA进行填充
# Out:
# 0    1200.0
# 1    2739.6
# 2    2133.0
# 3    5433.0
# 4     500.0
# 5    4432.0
# Name: price, dtype: float64

# %%
print(df['price'].astype('int'))  # 更改数据格式
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 print(df['price'].astype('int'))  # 更改数据格式
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34   500.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B',' ','110-C',' ','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])
# 创建数据帧

print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df['price'].fillna(df['price'].mean()))  # 使用列prince的均值对NA进行填充
# Out:
# 0    1200.0
# 1    3299.5
# 2    2133.0
# 3    5433.0
# 4    3299.5
# 5    4432.0
# Name: price, dtype: float64

# %%
print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df = df['price'].fillna(df['price'].mean())
print(df)  # 使用列prince的均值对NA进行填充
# Out:
# 0    1200.0
# 1    3299.5
# 2    2133.0
# 3    5433.0
# 4    3299.5
# 5    4432.0
# Name: price, dtype: float64

# %%
df['price']= df['price'].fillna(df['price'].mean())
print(df)  # 使用列prince的均值对NA进行填充
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 df['price']= df['price'].fillna(df['price'].mean())
#       2 print(df)  # 使用列prince的均值对NA进行填充
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# ...

# %%
print(df)
# Out:
# 0    1200.0
# 1    3299.5
# 2    2133.0
# 3    5433.0
# 4    3299.5
# 5    4432.0
# Name: price, dtype: float64

# %%
df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B',' ','110-C',' ','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])
# 创建数据帧

print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df['price'].fillna(df['price'].mean())
print(df)  # 使用列prince的均值对NA进行填充
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df.fillna(value=0)) # 对空值用0填充
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     0.0
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     0.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df['price'].fillna(df['price'].mean())
# Out:
# 0    1200.0
# 1    3299.5
# 2    2133.0
# 3    5433.0
# 4    3299.5
# 5    4432.0
# Name: price, dtype: float64

# %%
df.fillna(df['price'].mean())
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44  3299.5
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34  3299.5
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df['price'].astype('int'))  # 更改数据格式
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 print(df['price'].astype('int'))  # 更改数据格式
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df.fillna(df['price'].mean())
print(df)  # 使用列prince的均值对NA进行填充
df['city']=df['city'].map(str.strip)
print(df)  # 清除city字段的字符空格
df['city']=df['city'].str.lower()
print(df) # 大小写转换 upper(小转大)，lower(大转小)
print(df['price'].astype('int'))  # 更改数据格式
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou             54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai            34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0
#      id       date       city category  age   price
# 0  1001 2013-01-02    Beijing    100-A   23  1200.0
# 1  1002 2013-01-03         SH    100-B   44     NaN
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34     NaN
# 5  1006 2013-01-07    BEIJING    130-F   32  4432.0
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44     NaN
# 2  1003 2013-01-04  guangzhou            54  2133.0
# ...

# %%
df.fillna(df['price'].mean())
print(df)  # 使用列prince的均值对NA进行填充
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44     NaN
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34     NaN
# 5  1006 2013-01-07    beijing    130-F   32  4432.0

# %%
df.fillna(df['price'].mean())
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44  3299.5
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34  3299.5
# 5  1006 2013-01-07    beijing    130-F   32  4432.0

# %%
df['price'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 df['price'].astype('int')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
df = df['price'].astype('int')
print(df)  # 更改数据格式
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 df = df['price'].astype('int')
#       2 print(df)  # 更改数据格式
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
# ...

# %%
print(df)
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44     NaN
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34     NaN
# 5  1006 2013-01-07    beijing    130-F   32  4432.0

# %%
df.fillna(df['price'].mean())
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44  3299.5
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34  3299.5
# 5  1006 2013-01-07    beijing    130-F   32  4432.0

# %%
df.fillna(df['price'].mean())
print(df)  # 使用列prince的均值对NA进行填充
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44     NaN
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34     NaN
# 5  1006 2013-01-07    beijing    130-F   32  4432.0

# %%
print(df['city'].map(str.strip))  # 清除city字段的字符空格
# Out:
# 0      beijing
# 1           sh
# 2    guangzhou
# 3     shenzhen
# 4     shanghai
# 5      beijing
# Name: city, dtype: object

# %%
print(df.fillna(df['price'].mean()))  # 使用列prince的均值对NA进行填充
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44  3299.5
# 2  1003 2013-01-04  guangzhou            54  2133.0
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai            34  3299.5
# 5  1006 2013-01-07    beijing    130-F   32  4432.0

# %%
print(df['price'].astype('int'))  # 更改数据格式
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 print(df['price'].astype('int'))  # 更改数据格式
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

# %%
df['city']=df['city'].str.upper()
print(df) # 大小写转换 upper(小转大)，lower(大转小)
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    BEIJING    100-A   23  1200.0
# 1  1002 2013-01-03         SH    100-B   44     NaN
# 2  1003 2013-01-04  GUANGZHOU            54  2133.0
# 3  1004 2013-01-05   SHENZHEN    110-C   32  5433.0
# 4  1005 2013-01-06   SHANGHAI            34     NaN
# 5  1006 2013-01-07    BEIJING    130-F   32  4432.0

# %%
print(df)
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    BEIJING    100-A   23  1200.0
# 1  1002 2013-01-03         SH    100-B   44     NaN
# 2  1003 2013-01-04  GUANGZHOU            54  2133.0
# 3  1004 2013-01-05   SHENZHEN    110-C   32  5433.0
# 4  1005 2013-01-06   SHANGHAI            34     NaN
# 5  1006 2013-01-07    BEIJING    130-F   32  4432.0

# %%
df = pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006], 
 "date":pd.date_range('20130102', periods=6),
  "city":['Beijing ', 'SH', ' guangzhou ', 'Shenzhen', 'shanghai', 'BEIJING '],
 "age":[23,44,54,32,34,32],
 "category":['100-A','100-B','110-A','110-C','210-A','130-F'],
  "price":[1200,np.nan,2133,5433,np.nan,4432]},
  columns =['id','date','city','category','age','price'])
# 创建数据帧

print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df.fillna(df['price'].mean()))  # 使用列prince的均值对NA进行填充
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44  3299.5
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df.fillna(df['price'].mean()))  # 使用列prince的均值对NA进行填充
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44  3299.5
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     Beijing     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df['city']=df['city'].str.upper()

# %%
df.fillna(df['price'].mean())
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02     BEIJING     100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44  3299.5
# 2  1003 2013-01-04   GUANGZHOU     110-A   54  2133.0
# 3  1004 2013-01-05     SHENZHEN    110-C   32  5433.0
# 4  1005 2013-01-06     SHANGHAI    210-A   34  3299.5
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
print(df.fillna(df['price'].mean(),inplace=true))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 print(df.fillna(df['price'].mean(),inplace=true))
#
# NameError: name 'true' is not defined

# %%
print(df.fillna(df['price'].mean(),inplace=True))
# Out:
# None

# %%
print(df['price'].astype('int'))  # 更改数据格式
# Out:
# 0    1200
# 1    3299
# 2    2133
# 3    5433
# 4    3299
# 5    4432
# Name: price, dtype: int32

# %%
print(df.rename(columns={'category': 'category-size'}))  # 更改列名称：
# Out:
#      id       date         city category-size  age   price
# 0  1001 2013-01-02     BEIJING          100-A   23  1200.0
# 1  1002 2013-01-03           SH         100-B   44  3299.5
# 2  1003 2013-01-04   GUANGZHOU          110-A   54  2133.0
# 3  1004 2013-01-05     SHENZHEN         110-C   32  5433.0
# 4  1005 2013-01-06     SHANGHAI         210-A   34  3299.5
# 5  1006 2013-01-07     BEIJING          130-F   32  4432.0

# %%
print(df['city'].drop_duplicates())  #删除后出现的重复值
# Out:
# 0       BEIJING
# 1             SH
# 2     GUANGZHOU
# 3       SHENZHEN
# 4       SHANGHAI
# Name: city, dtype: object

# %%
print(df['city'].replace('sh','shanghai')) # 数据替换
# Out:
# 0       BEIJING
# 1             SH
# 2     GUANGZHOU
# 3       SHENZHEN
# 4       SHANGHAI
# 5       BEIJING
# Name: city, dtype: object

# %%
df['city']=df['city'].str.lower()

# %%
print(df['city'].replace('sh','shanghai')) # 数据替换
# Out:
# 0       beijing
# 1       shanghai
# 2     guangzhou
# 3       shenzhen
# 4       shanghai
# 5       beijing
# Name: city, dtype: object

# %%
df1=pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006,1007,1008], 
"gender":['male','female','male','female','male','female','male','female'],
"pay":['Y','N','Y','Y','N','Y','N','Y',],
"m-point":[10,12,20,40,40,40,30,20]})
# 数据预处理

df_inner=pd.merge(df,df1,how='inner')  # 匹配合并，交集
df_left=pd.merge(df,df1,how='left')        #
df_right=pd.merge(df,df1,how='right')
df_outer=pd.merge(df,df1,how='outer')  #并集

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 'B': ['B0', 'B1', 'B2', 'B3'],'C': ['C0', 'C1', 'C2', 'C3'],'D': ['D0', 'D1', 'D2', 'D3']},index=[0, 1, 2, 3])  
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],'B': ['B4', 'B5', 'B6', 'B7'],'C': ['C4', 'C5', 'C6', 'C7'],'D': ['D4', 'D5', 'D6', 'D7']},index=[4, 5, 6, 7])  
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],'B': ['B8', 'B9', 'B10', 'B11'],'C': ['C8', 'C9', 'C10', 'C11'],'D': ['D8', 'D9', 'D10', 'D11']},index=[8, 9, 10, 11])  

df1
# 数据预处理

df_inner=pd.merge(df,df1,how='inner')  # 匹配合并，交集
df_left=pd.merge(df,df1,how='left')        #
df_right=pd.merge(df,df1,how='right')
df_outer=pd.merge(df,df1,how='outer')  #并集
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
#       6 # 数据预处理
#       7
# ----> 8 df_inner=pd.merge(df,df1,how='inner')  # 匹配合并，交集
#       9 df_left=pd.merge(df,df1,how='left')        #
#      10 df_right=pd.merge(df,df1,how='right')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# ...

# %%
result = pd.concat([df1,df2,df3])  

print(result)
# 使用concat进行合并
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],'D': ['D2', 'D3', 'D6', 'D7'],'F': ['F2', 'F3', 'F6', 'F7']},index=[2, 3, 6, 7])  
result2=pd.concat([df1,df4],axis=1)  

print(result2) 
# 新建一个数据帧df4，将df1与df4进行列项合并，axis=1。
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result3=pd.concat([df1,df4],axis=1,join='inner')  

print(result3)
# df1与df4进行列项合并axis=1，合并方式为内部合并join=‘inner’
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
result5=pd.concat([df1,df4],ignore_index=True)  

print(result5)  
# 将df1与df4合并，忽略行索引ignore_index=True
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
s1=pd.Series(['X0', 'X1', 'X2', 'X3'],name='X')  
result6=pd.concat([df1,s1],axis=1)  

print(result6)
# 创建一个名为s1的Series值为[‘X0’, ‘X1’, ‘X2’, ‘X3’]，name=‘X’，将df1与s1进行列项合并
# Out:
#     A   B   C   D   X
# 0  A0  B0  C0  D0  X0
# 1  A1  B1  C1  D1  X1
# 2  A2  B2  C2  D2  X2
# 3  A3  B3  C3  D3  X3

# %%
result=pd.concat([df1,s1],axis=1,ignore_index=True)  

print(df1,s1,result) 
# 将df1与s1进行列项合并，忽略索引 ignore_index=True
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3 0    X0
# 1    X1
# 2    X2
# 3    X3
# Name: X, dtype: object     0   1   2   3   4
# 0  A0  B0  C0  D0  X0
# 1  A1  B1  C1  D1  X1
# 2  A2  B2  C2  D2  X2
# 3  A3  B3  C3  D3  X3

# %%
pieces={'x':df1,'y':df2,'z':df3}  
result = pd.concat(pieces, keys=['z', 'y'])  
print(pieces)

print(result)
# 将df1,df2,df3,作为值，x,y,z作为键构建名为pieces的字典，然后对pieces使用concat进行合并，并令参数keys=[‘z’,‘y’]
# Out:
# {'x':     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3, 'y':     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7, 'z':       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11}
#         A    B    C    D
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7

# %%
df1.append(df2)  
# 使用append方法将df1与df2合并
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pieces={'x':df1,'y':df2,'z':df3}  
result = pd.concat(pieces, keys=['z', 'y'])  
pieces

result
# 将df1,df2,df3,作为值，x,y,z作为键构建名为pieces的字典，然后对pieces使用concat进行合并，并令参数keys=[‘z’,‘y’]
# Out:
#         A    B    C    D
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7

# %%
pieces={'x':df1,'y':df2,'z':df3}  
result = pd.concat(pieces, keys=['z', 'y'])  

pieces
# 将df1,df2,df3,作为值，x,y,z作为键构建名为pieces的字典，然后对pieces使用concat进行合并，并令参数keys=[‘z’,‘y’]
# Out:
# {'x':     A   B   C   D
#  0  A0  B0  C0  D0
#  1  A1  B1  C1  D1
#  2  A2  B2  C2  D2
#  3  A3  B3  C3  D3, 'y':     A   B   C   D
#  4  A4  B4  C4  D4
#  5  A5  B5  C5  D5
#  6  A6  B6  C6  D6
#  7  A7  B7  C7  D7, 'z':       A    B    C    D
#  8    A8   B8   C8   D8
#  9    A9   B9   C9   D9
#  10  A10  B10  C10  D10
#  11  A11  B11  C11  D11}

# %%
df1.append(df4)
# 使用append方法将df1与df4合并
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
df1.append([df2,df3])  
# 使用append方法将df1与df2、df3合并
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result=df1.append(df4,ignore_index=True)  

result
# 将df1与df4进行合并，忽略索引ignore_index=True
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],'A': ['A0', 'A1', 'A2', 'A3'], 'B': ['B0', 'B1', 'B2', 'B3']})  
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']})  
result = pd.merge(left, right, on='key')  

print( left,right,result)  
# 创建两个数据帧left、right，使用merge函数按key列将left与right进行连接
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'], 'key2': ['K0', 'K1', 'K0', 'K1'],'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3']})  
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],'key2': ['K0', 'K0', 'K0', 'K0'],'C': ['C0', 'C1', 'C2', 'C3'],'D': ['D0', 'D1', 'D2', 'D3']})  
result = pd.merge(left, right, on=['key1', 'key2'])  

print( left,right,result)  
# 创建两个数据帧left、right，使用merge函数按[key1，key2]列将left与right进行连接(复合key的合并方法，使用merge的时候可以选择多个key作为复合可以来对齐合并)
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'], 'key2': ['K0', 'K1', 'K0', 'K1'],'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3']})  
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],'key2': ['K0', 'K0', 'K0', 'K0'],'C': ['C0', 'C1', 'C2', 'C3'],'D': ['D0', 'D1', 'D2', 'D3']})  
result = pd.merge(left, right, how='left', on=['key1', 'key2'])  

print( left,right,result)  
# 使用merge函数按[key1，key2]列将left与right进行左表连接
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
result = pd.merge(left, right, how='right', on=['key1', 'key2'])  

print(result) 
# 使用merge函数按[key1，key2]列将left与right进行右表连接
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
df1=pd.DataFrame({"id":[1001,1002,1003,1004,1005,1006,1007,1008], 
"gender":['male','female','male','female','male','female','male','female'],
"pay":['Y','N','Y','Y','N','Y','N','Y',],
"m-point":[10,12,20,40,40,40,30,20]})
# 数据预处理

df_inner=pd.merge(df,df1,how='inner')  # 匹配合并，交集
df_left=pd.merge(df,df1,how='left')        #
df_right=pd.merge(df,df1,how='right')

df_outer=pd.merge(df,df1,how='outer')  #并集
# 表格合并

df_inner.set_index('id')
# 设置索引列
# Out:
#            date         city category  age   price  gender pay  m-point
# id
# 1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40

# %%
df_inner.sort_values(by=['age'])
# 按照特定列的值排序
# Out:
#      id       date         city category  age   price  gender pay  m-point
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20

# %%
df_inner.sort_index()
# 按照索引列排序
# Out:
#      id       date         city category  age   price  gender pay  m-point
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40

# %%
df_inner['group'] = np.where(df_inner['price'] > 3000,'high','low')
# 如果prince列的值>3000，group列显示high，否则显示low

# %%
df_inner['group'] = np.where(df_inner['price'] > 3000,'high','low')

print(df_inner)
# 如果prince列的值>3000，group列显示high，否则显示low
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group
# 0   low
# 1  high
# 2   low
# 3  high
# 4  high
# 5  high

# %%
df_inner.loc[(df_inner['city'] == 'beijing') & (df_inner['price'] >= 4000), 'sign']=1
# 对复合多个条件的数据进行分组标记

# %%
df_inner.loc[(df_inner['city'] == 'beijing') & (df_inner['price'] >= 4000), 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group  sign
# 0   low   NaN
# 1  high   NaN
# 2   low   NaN
# 3  high   NaN
# 4  high   NaN
# 5  high   NaN

# %%
df_inner.loc[(df_inner['city'] == 'beijing') & (df_inner['price'] >= 4000), 'sign']=1

# %%
df_inner.loc[(df_inner['city'] == 'beijing') , 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group  sign
# 0   low   NaN
# 1  high   NaN
# 2   low   NaN
# 3  high   NaN
# 4  high   NaN
# 5  high   NaN

# %%
df_inner.loc[(df_inner['price'] >= 4000), 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group  sign
# 0   low   NaN
# 1  high   NaN
# 2   low   NaN
# 3  high   1.0
# 4  high   NaN
# 5  high   1.0

# %%
df_inner.loc[(df_inner['city'] == 'sh') & (df_inner['price'] >= 2000), 'sign']=1

# %%
df_inner.loc[(df_inner['city'] == 'sh') & (df_inner['price'] >= 2000), 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group  sign
# 0   low   NaN
# 1  high   1.0
# 2   low   NaN
# 3  high   1.0
# 4  high   NaN
# 5  high   1.0

# %%
df_inner.loc[ (df_inner['city'] == 'sh') & (df_inner['price'] >= 2000), 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group  sign
# 0   low   NaN
# 1  high   1.0
# 2   low   NaN
# 3  high   1.0
# 4  high   NaN
# 5  high   1.0

# %%
df_inner.loc[ (df_inner['city'] == 'guangzhou') & (df_inner['price'] >= 2000), 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group  sign
# 0   low   NaN
# 1  high   1.0
# 2   low   NaN
# 3  high   1.0
# 4  high   NaN
# 5  high   1.0

# %%
df_inner.loc[ (df_inner['city'] == 'guangzhou') & (df_inner['price'] >= 2000), 'sign']='A'

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group sign
# 0   low  NaN
# 1  high    1
# 2   low  NaN
# 3  high    1
# 4  high  NaN
# 5  high    1

# %%
df_inner.loc[ (df_inner['city'] == 'guangzhou') & (df_inner['price'] >= 2000), 'sign']='B'

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group sign
# 0   low  NaN
# 1  high    1
# 2   low  NaN
# 3  high    1
# 4  high  NaN
# 5  high    1

# %%
df_inner.loc[ (df_inner['city'] == 'guangzhou') & (df_inner['price'] >= 2000), 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group sign
# 0   low  NaN
# 1  high    1
# 2   low  NaN
# 3  high    1
# 4  high  NaN
# 5  high    1

# %%
df_inner.loc[(df_inner['city'] == 'beijing') & (df_inner['price'] >= 4000), 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记
# Out:
#      id       date         city category  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing     100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh    100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou     110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen    110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai    210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing     130-F   32  4432.0  female   Y       40
#
#   group sign
# 0   low  NaN
# 1  high    1
# 2   low  NaN
# 3  high    1
# 4  high  NaN
# 5  high    1

# %%
pd.DataFrame((x.split('-') for x in df_inner['category']),index=df_inner.index,columns=['category','size'])
# 对category字段的值依次进行分列，并创建数据表，索引值为df_inner的索引列，列名称为category和size
# Out:
#   category size
# 0      100    A
# 1      100    B
# 2      110    A
# 3      110    C
# 4      210    A
# 5      130    F

# %%
split = pd.DataFrame((x.split('-') for x in df_inner['category']),index=df_inner.index,columns=['category','size'])

split
# 对category字段的值依次进行分列，并创建数据表，索引值为df_inner的索引列，列名称为category和size
# Out:
#   category size
# 0      100    A
# 1      100    B
# 2      110    A
# 3      110    C
# 4      210    A
# 5      130    F

# %%
df_inner=pd.merge(df_inner,split,right_index=True, left_index=True)
# 将完成分裂后的数据表和原df_inner数据表进行匹配

# %%
df_inner=pd.merge(df_inner,split,right_index=True, left_index=True)

df_inner
# 将完成分裂后的数据表和原df_inner数据表进行匹配
# Out:
#      id       date         city category_x  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing       100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh      100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou       110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen      110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai      210-A   34  3299.5    male   N       40
# 5  1006 2013-01-07     beijing       130-F   32  4432.0  female   Y       40
#
#   group sign category_y size_x category size_y
# 0   low  NaN        100      A      100      A
# 1  high    1        100      B      100      B
# 2   low  NaN        110      A      110      A
# 3  high    1        110      C      110      C
# 4  high  NaN        210      A      210      A
# 5  high    1        130      F      130      F

# %%
df_inner.loc[3]
# 按索引提取单行的数值
# Out:
# id                           1004
# date          2013-01-05 00:00:00
# city                     shenzhen
# category_x                  110-C
# age                            32
# price                        5433
# gender                     female
# pay                             Y
# m-point                        40
# group                        high
# sign                            1
# category_y                    110
# size_x                          C
# category                      110
# size_y                          C
# Name: 3, dtype: object

# %%
df_inner.iloc[0:5]
# 按索引提取区域行数值
# Out:
#      id       date         city category_x  age   price  gender pay  m-point  \
# 0  1001 2013-01-02     beijing       100-A   23  1200.0    male   Y       10
# 1  1002 2013-01-03           sh      100-B   44  3299.5  female   N       12
# 2  1003 2013-01-04   guangzhou       110-A   54  2133.0    male   Y       20
# 3  1004 2013-01-05     shenzhen      110-C   32  5433.0  female   Y       40
# 4  1005 2013-01-06     shanghai      210-A   34  3299.5    male   N       40
#
#   group sign category_y size_x category size_y
# 0   low  NaN        100      A      100      A
# 1  high    1        100      B      100      B
# 2   low  NaN        110      A      110      A
# 3  high    1        110      C      110      C
# 4  high  NaN        210      A      210      A

# %%
df_inner.reset_index()
# 重设索引
# Out:
#    index    id       date         city category_x  age   price  gender pay  \
# 0      0  1001 2013-01-02     beijing       100-A   23  1200.0    male   Y
# 1      1  1002 2013-01-03           sh      100-B   44  3299.5  female   N
# 2      2  1003 2013-01-04   guangzhou       110-A   54  2133.0    male   Y
# 3      3  1004 2013-01-05     shenzhen      110-C   32  5433.0  female   Y
# 4      4  1005 2013-01-06     shanghai      210-A   34  3299.5    male   N
# 5      5  1006 2013-01-07     beijing       130-F   32  4432.0  female   Y
#
#    m-point group sign category_y size_x category size_y
# 0       10   low  NaN        100      A      100      A
# 1       12  high    1        100      B      100      B
# 2       20   low  NaN        110      A      110      A
# 3       40  high    1        110      C      110      C
# 4       40  high  NaN        210      A      210      A
# 5       40  high    1        130      F      130      F

# %%
df_inner=df_inner.set_index('date') 
#  设置日期为索引

# %%
df_inner=df_inner.set_index('date') 

df_inner
#  设置日期为索引
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ...

# %%
df_inner=df_inner.set_index('date') 

df_inner[:'2013-01-04']
#  设置日期为索引
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ...

# %%
df_inner.reset_index()
# 重设索引
# Out:
#         date    id         city category_x  age   price  gender pay  m-point  \
# 0 2013-01-02  1001     beijing       100-A   23  1200.0    male   Y       10
# 1 2013-01-03  1002           sh      100-B   44  3299.5  female   N       12
# 2 2013-01-04  1003   guangzhou       110-A   54  2133.0    male   Y       20
# 3 2013-01-05  1004     shenzhen      110-C   32  5433.0  female   Y       40
# 4 2013-01-06  1005     shanghai      210-A   34  3299.5    male   N       40
# 5 2013-01-07  1006     beijing       130-F   32  4432.0  female   Y       40
#
#   group sign category_y size_x category size_y
# 0   low  NaN        100      A      100      A
# 1  high    1        100      B      100      B
# 2   low  NaN        110      A      110      A
# 3  high    1        110      C      110      C
# 4  high  NaN        210      A      210      A
# 5  high    1        130      F      130      F

# %%
df_inner[:'2013-01-04']
#  设置日期为索引
# Out:
#               id         city category_x  age   price  gender pay  m-point  \
# date
# 2013-01-02  1001     beijing       100-A   23  1200.0    male   Y       10
# 2013-01-03  1002           sh      100-B   44  3299.5  female   N       12
# 2013-01-04  1003   guangzhou       110-A   54  2133.0    male   Y       20
#
#            group sign category_y size_x category size_y
# date
# 2013-01-02   low  NaN        100      A      100      A
# 2013-01-03  high    1        100      B      100      B
# 2013-01-04   low  NaN        110      A      110      A

# %%
df_inner.iloc[:3,:2] #冒号前后的数字不再是索引的标签名称，而是数据所在的位置，从0开始，前三行，前两列。
# 使用iloc按位置区域提取数据
# Out:
#               id         city
# date
# 2013-01-02  1001     beijing
# 2013-01-03  1002           sh
# 2013-01-04  1003   guangzhou

# %%
df_inner.iloc[[0,2,5],[4,5]] #提取第0、2、5行，4、5列
# 适应iloc按位置单独提起数据
# Out:
#              price  gender
# date
# 2013-01-02  1200.0    male
# 2013-01-04  2133.0    male
# 2013-01-07  4432.0  female

# %%
df_inner.ix[:'2013-01-03',:4] #2013-01-03号之前，前四列数据
# 使用ix按索引标签和位置混合提取数据
# Out:
# c:\carl\PythonExcel\pandas book\pandascsdn1.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#               id      city category_x  age
# date
# 2013-01-02  1001  beijing       100-A   23
# 2013-01-03  1002        sh      100-B   44

# %%
df_inner['city'].isin(['beijing'])
# 判断city列的值是否为北京
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner['city'].astype('str')
df_inner.loc[(df_inner['city'] == 'beijing') & (df_inner['price'] >= 4000), 'sign']=1

print(df_inner)
# 对复合多个条件的数据进行分组标记(有问题)
# Out:
#               id         city category_x  age   price  gender pay  m-point  \
# date
# 2013-01-02  1001     beijing       100-A   23  1200.0    male   Y       10
# 2013-01-03  1002           sh      100-B   44  3299.5  female   N       12
# 2013-01-04  1003   guangzhou       110-A   54  2133.0    male   Y       20
# 2013-01-05  1004     shenzhen      110-C   32  5433.0  female   Y       40
# 2013-01-06  1005     shanghai      210-A   34  3299.5    male   N       40
# 2013-01-07  1006     beijing       130-F   32  4432.0  female   Y       40
#
#            group sign category_y size_x category size_y
# date
# 2013-01-02   low  NaN        100      A      100      A
# 2013-01-03  high    1        100      B      100      B
# 2013-01-04   low  NaN        110      A      110      A
# 2013-01-05  high    1        110      C      110      C
# 2013-01-06  high  NaN        210      A      210      A
# 2013-01-07  high    1        130      F      130      F

# %%
df_inner['city'].isin(['beijing'])
# 判断city列的值是否为北京(问题出在这里)
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner['city'].astype('str')

df_inner['city'].isin(['beijing'])
# 判断city列的值是否为北京(问题出在这里)
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner['city'].astype('str')
# Out:
# date
# 2013-01-02       beijing
# 2013-01-03             sh
# 2013-01-04     guangzhou
# 2013-01-05       shenzhen
# 2013-01-06       shanghai
# 2013-01-07       beijing
# Name: city, dtype: object

# %%
df_inner['city'].isin(['beijing'])
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner['city'].isin(['sh'])
# Out:
# date
# 2013-01-02    False
# 2013-01-03     True
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner['city'].isin(['beijing'])
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner['city'].isin(['shanghai'])
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06     True
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner['city'].isin(['guangzhou'])
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner.loc[df_inner['city'].isin(['beijing','shanghai'])] 
# 判断city列里是否包含beijing和shanghai，然后将符合条件的数据提取出来
# Out:
#               id      city category_x  age   price gender pay  m-point group  \
# date
# 2013-01-06  1005  shanghai      210-A   34  3299.5   male   N       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-06  NaN        210      A      210      A

# %%
df_inner.loc[df_inner['city'].isin(['sh','shanghai'])] 
# 判断city列里是否包含beijing和shanghai，然后将符合条件的数据提取出来
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-03  1002        sh      100-B   44  3299.5  female   N       12  high
# 2013-01-06  1005  shanghai      210-A   34  3299.5    male   N       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-03    1        100      B      100      B
# 2013-01-06  NaN        210      A      210      A

# %%
df_inner.loc[df_inner['city'].isin(['sh','shanghai','shenzhen'])] 
# 判断city列里是否包含beijing和shanghai，然后将符合条件的数据提取出来
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-03  1002        sh      100-B   44  3299.5  female   N       12  high
# 2013-01-05  1004  shenzhen      110-C   32  5433.0  female   Y       40  high
# 2013-01-06  1005  shanghai      210-A   34  3299.5    male   N       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-03    1        100      B      100      B
# 2013-01-05    1        110      C      110      C
# 2013-01-06  NaN        210      A      210      A

# %%
df_inner.loc[df_inner['city'].isin(['beijing','shanghai','shenzhen'])] 
# 判断city列里是否包含beijing和shanghai，然后将符合条件的数据提取出来
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-05  1004  shenzhen      110-C   32  5433.0  female   Y       40  high
# 2013-01-06  1005  shanghai      210-A   34  3299.5    male   N       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-05    1        110      C      110      C
# 2013-01-06  NaN        210      A      210      A

# %%
categ1 = pd.DataFrame(df_inner['category'].str[:3])
print(categ1)
# Out:
#            category
# date
# 2013-01-02      100
# 2013-01-03      100
# 2013-01-04      110
# 2013-01-05      110
# 2013-01-06      210
# 2013-01-07      130

# %%
df['city']=df['city'].map(str.strip)

# %%
df_inner.loc[df_inner['city'].isin(['beijing','shanghai','shenzhen'])] 
# 判断city列里是否包含beijing和shanghai，然后将符合条件的数据提取出来,beijing和guangzhou始终是bug
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-05  1004  shenzhen      110-C   32  5433.0  female   Y       40  high
# 2013-01-06  1005  shanghai      210-A   34  3299.5    male   N       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-05    1        110      C      110      C
# 2013-01-06  NaN        210      A      210      A

# %%
df_inner['city'].map(str.strip)
# Out:
# date
# 2013-01-02      beijing
# 2013-01-03           sh
# 2013-01-04    guangzhou
# 2013-01-05     shenzhen
# 2013-01-06     shanghai
# 2013-01-07      beijing
# Name: city, dtype: object

# %%
df_inner['city'].map(str.strip)
df_inner['city'].astype('str')

df_inner['city'].isin(['guangzhou'])
# 判断city列的值是否为北京(有问题)
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07    False
# Name: city, dtype: bool

# %%
df_inner.loc[df_inner['city'].isin(['beijing','shanghai','shenzhen'])]
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-05  1004  shenzhen      110-C   32  5433.0  female   Y       40  high
# 2013-01-06  1005  shanghai      210-A   34  3299.5    male   N       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-05    1        110      C      110      C
# 2013-01-06  NaN        210      A      210      A

# %%
df_inner.loc[(df_inner['age'] > 25) & (df_inner['city'] == 'sh'), ['id','city','age','category','gender']]
# 使用“与”进行筛选
# Out:
#               id city  age category  gender
# date
# 2013-01-03  1002   sh   44      100  female

# %%
df_inner.loc[(df_inner['age'] > 25) | (df_inner['city'] == 'shenzhen'), ['id','city','age','category','gender']].sort(['age']) 
# 使用“或”进行筛选
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 df_inner.loc[(df_inner['age'] > 25) | (df_inner['city'] == 'shenzhen'), ['id','city','age','category','gender']].sort(['age'])
#       2 # 使用“或”进行筛选
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
df_inner.loc[(df_inner['age'] > 25) | (df_inner['city'] == 'beijing'), ['id','city','age','category','gender']].sort(['age']) 
# 使用“或”进行筛选
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 df_inner.loc[(df_inner['age'] > 25) | (df_inner['city'] == 'beijing'), ['id','city','age','category','gender']].sort(['age'])
#       2 # 使用“或”进行筛选
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
df_inner.loc[(df_inner['age'] > 25) & (df_inner['city'] == 'sh'), ['id','city','age','category','gender']]
# Out:
#               id city  age category  gender
# date
# 2013-01-03  1002   sh   44      100  female

# %%
df_inner.loc[(df_inner['age'] > 25) | (df_inner['city'] == 'beijing'), ['id','city','age','category','gender']].sort_values(['age']) 
# 使用“或”进行筛选
# Out:
#               id         city  age category  gender
# date
# 2013-01-05  1004     shenzhen   32      110  female
# 2013-01-07  1006     beijing    32      130  female
# 2013-01-06  1005     shanghai   34      210    male
# 2013-01-03  1002           sh   44      100  female
# 2013-01-04  1003   guangzhou    54      110    male

# %%
df_inner.loc[(df_inner['city'] != 'beijing'), ['id','city','age','category','gender']].sort_values(['id'])
# Out:
#               id         city  age category  gender
# date
# 2013-01-02  1001     beijing    23      100    male
# 2013-01-03  1002           sh   44      100  female
# 2013-01-04  1003   guangzhou    54      110    male
# 2013-01-05  1004     shenzhen   32      110  female
# 2013-01-06  1005     shanghai   34      210    male
# 2013-01-07  1006     beijing    32      130  female

# %%
df_inner.loc[(df_inner['city'] != 'sh'), ['id','city','age','category','gender']].sort_values(['id'])
# Out:
#               id         city  age category  gender
# date
# 2013-01-02  1001     beijing    23      100    male
# 2013-01-04  1003   guangzhou    54      110    male
# 2013-01-05  1004     shenzhen   32      110  female
# 2013-01-06  1005     shanghai   34      210    male
# 2013-01-07  1006     beijing    32      130  female

# %%
df_inner.loc[(df_inner['age'] > 25) | (df_inner['city'] == 'sh'), ['id','city','age','category','gender']].sort_values(['age']) 
# 使用“或”进行筛选
# Out:
#               id         city  age category  gender
# date
# 2013-01-05  1004     shenzhen   32      110  female
# 2013-01-07  1006     beijing    32      130  female
# 2013-01-06  1005     shanghai   34      210    male
# 2013-01-03  1002           sh   44      100  female
# 2013-01-04  1003   guangzhou    54      110    male

# %%
df_inner.loc[(df_inner['city'] != 'beijing'), ['id','city','age','category','gender']].sort_values(['id']).city.count()
# Out:
# 6

# %%
df_inner.loc[(df_inner['city'] != 'sh'), ['id','city','age','category','gender']].sort_values(['id']).city.count()
# 对筛选后的数据按city列进行计数
# Out:
# 5

# %%
df_inner.query('city == ["shenzhen", "shanghai"]')
# 使用query函数进行筛选
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-05  1004  shenzhen      110-C   32  5433.0  female   Y       40  high
# 2013-01-06  1005  shanghai      210-A   34  3299.5    male   N       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-05    1        110      C      110      C
# 2013-01-06  NaN        210      A      210      A

# %%
df_inner.query('city == ["shenzhen", "shanghai"]').price.sum()
# Out:
# 8732.5

# %%
df_inner.groupby('city').count()
# 对所有的列进行计数汇总
# Out:
#              id  category_x  age  price  gender  pay  m-point  group  sign  \
# city
#  guangzhou    1           1    1      1       1    1        1      1     0
# beijing       2           2    2      2       2    2        2      2     1
# sh            1           1    1      1       1    1        1      1     1
# shanghai      1           1    1      1       1    1        1      1     0
# shenzhen      1           1    1      1       1    1        1      1     1
#
#              category_y  size_x  category  size_y
# city
#  guangzhou            1       1         1       1
# beijing               2       2         2       2
# sh                    1       1         1       1
# shanghai              1       1         1       1
# shenzhen              1       1         1       1

# %%
df_inner.groupby('city')['id'].count()
# 按城市对id字段进行计数
# Out:
# city
#  guangzhou     1
# beijing        2
# sh             1
# shanghai       1
# shenzhen       1
# Name: id, dtype: int64

# %%
df_inner.groupby(['city','size'])['id'].count()
# 对两个字段进行汇总计数
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\carl\PythonExcel\pandas book\pandascsdn1.py in <module>()
# ----> 1 df_inner.groupby(['city','size'])['id'].count()
#       2 # 对两个字段进行汇总计数
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
# ...

# %%
df_inner.groupby(['city','size_x'])['id'].count()
# 对两个字段进行汇总计数
# Out:
# city         size_x
#  guangzhou   A         1
# beijing      A         1
#              F         1
# sh           B         1
# shanghai     A         1
# shenzhen     C         1
# Name: id, dtype: int64

# %%
df_inner.groupby('city')['price'].agg([len,np.sum, np.mean]) 
# 对city字段进行汇总，并分别计算prince的合计和均值
# Out:
#              len     sum    mean
# city
#  guangzhou   1.0  2133.0  2133.0
# beijing      2.0  5632.0  2816.0
# sh           1.0  3299.5  3299.5
# shanghai     1.0  3299.5  3299.5
# shenzhen     1.0  5433.0  5433.0

# %%
df_inner.sample(n=3) 
# 简单的数据采样
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-07  1006  beijing       130-F   32  4432.0  female   Y       40  high
# 2013-01-06  1005  shanghai      210-A   34  3299.5    male   N       40  high
# 2013-01-05  1004  shenzhen      110-C   32  5433.0  female   Y       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-07    1        130      F      130      F
# 2013-01-06  NaN        210      A      210      A
# 2013-01-05    1        110      C      110      C

# %%
df_inner.sample(n=3) 
# 简单的数据采样
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-07  1006  beijing       130-F   32  4432.0  female   Y       40  high
# 2013-01-02  1001  beijing       100-A   23  1200.0    male   Y       10   low
# 2013-01-03  1002        sh      100-B   44  3299.5  female   N       12  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-07    1        130      F      130      F
# 2013-01-02  NaN        100      A      100      A
# 2013-01-03    1        100      B      100      B

# %%
weights = [0, 0, 0, 0, 0.5, 0.5]

df_inner.sample(n=2, weights=weights) 
# 手动设置采样权重
# Out:
#               id      city category_x  age   price  gender pay  m-point group  \
# date
# 2013-01-06  1005  shanghai      210-A   34  3299.5    male   N       40  high
# 2013-01-07  1006  beijing       130-F   32  4432.0  female   Y       40  high
#
#            sign category_y size_x category size_y
# date
# 2013-01-06  NaN        210      A      210      A
# 2013-01-07    1        130      F      130      F

# %%
df_inner.sample(n=6, replace=False) 
# 采样后不放回
# Out:
#               id         city category_x  age   price  gender pay  m-point  \
# date
# 2013-01-04  1003   guangzhou       110-A   54  2133.0    male   Y       20
# 2013-01-05  1004     shenzhen      110-C   32  5433.0  female   Y       40
# 2013-01-06  1005     shanghai      210-A   34  3299.5    male   N       40
# 2013-01-07  1006     beijing       130-F   32  4432.0  female   Y       40
# 2013-01-03  1002           sh      100-B   44  3299.5  female   N       12
# 2013-01-02  1001     beijing       100-A   23  1200.0    male   Y       10
#
#            group sign category_y size_x category size_y
# date
# 2013-01-04   low  NaN        110      A      110      A
# 2013-01-05  high    1        110      C      110      C
# 2013-01-06  high  NaN        210      A      210      A
# 2013-01-07  high    1        130      F      130      F
# 2013-01-03  high    1        100      B      100      B
# 2013-01-02   low  NaN        100      A      100      A

# %%
df_inner.describe().round(2).T #round函数设置显示小数位，T表示转置
# 数据表描述性统计
# Out:
#          count    mean      std     min      25%     50%      75%     max
# id         6.0  1003.5     1.87  1001.0  1002.25  1003.5  1004.75  1006.0
# age        6.0    36.5    10.88    23.0    32.00    33.0    41.50    54.0
# price      6.0  3299.5  1523.35  1200.0  2424.62  3299.5  4148.88  5433.0
# m-point    6.0    27.0    14.63    10.0    14.00    30.0    40.00    40.0

# %%
df_inner['price'].std()
# 计算列的标准差
# Out:
# 1523.3516337339847

# %%
df_inner['price'].cov(df_inner['m-point']) 
# 计算两个字段间的协方差
# Out:
# 17263.0

# %%
df_inner.cov()
# 数据表中所有字段间的协方差
# Out:
#              id     age      price  m-point
# id          3.5    -0.7     1946.0     25.4
# age        -0.7   118.3    -1353.5    -31.0
# price    1946.0 -1353.5  2320600.2  17263.0
# m-point    25.4   -31.0    17263.0    214.0

# %%
df_inner['price'].corr(df_inner['m-point']) #相关系数在-1到1之间，接近1为正相关，接近-1为负相关，0为不相关
# 两个字段的相关性分析
# Out:
# 0.7746565925361043

# %%
df_inner.corr()
# 数据表的相关性分析
# Out:
#                id       age     price   m-point
# id       1.000000 -0.034401  0.682824  0.928096
# age     -0.034401  1.000000 -0.081689 -0.194833
# price    0.682824 -0.081689  1.000000  0.774657
# m-point  0.928096 -0.194833  0.774657  1.000000
